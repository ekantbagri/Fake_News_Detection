# %%
# !pip install tweepy

# %%
import tweepy

consumer_key = 'LznE5GREoRbyGnBbUMhgucjJE'
consumer_secret = '0gVlRYkOvufeU1Zgl9zczD6NHqKcUxzAJLrNmbSks0Vcwodkht'
access_token = '3281755855-eRY7sd06dTxA3A6jF86ogb8Nwgmv8uA1NpjPUWr'
access_token_secret = 'kngcKANCU4XMPy39eVvTyvGIVyJPiLRnIMneeMNdKAbtD'
                   
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
search_results=api.search(q='covid',count=20)
